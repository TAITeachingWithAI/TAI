# %% [markdown]
# # Working with a neural network — write it yourself with AI
#
# In this version **you** build and train the neural network, with the help of an AI language model
# (LLM).
#
# The planet data is loaded for you below. For each exercise, read what you need to do, ask the AI
# to help you write the Python code, run it, and check the result. If you get an error, paste it
# back to the AI and ask it to fix the code.
#
# A neural network is a flexible model with many adjustable weights. The computer tunes the weights
# automatically by minimising the loss (this is called *training*). A convenient tool for a small
# network is `MLPRegressor` from the library `scikit-learn`.

# %% [markdown]
# ## How to use this notebook
#
# New to Google Colab? A few basics:
#
# - **Run a cell** by clicking it and pressing **Shift + Enter** (or click the **▶** button on its left).
# - **Run the cells in order, from top to bottom.** A cell often needs things set up by the cells above it, so if you skip one you may get an error (for example a `NameError`).
# - The first time you run something, Colab may warn that the notebook **was not authored by Google**. Click **Run anyway**; this notebook only does calculations and makes plots.
# - If a cell shows a **red error**, read the **last line**, fix it (or ask your AI tutor) and run the cell again.
# - Anything you type or produce here is temporary, which is fine for this lesson.

# %% [markdown]
# > **Tips for working with the AI**
# >
# > - Tell it your data: a pandas DataFrame `planets` with columns `T_years` (period, years) and
# >   `a_au` (semi-major axis, AU). You want to **predict `a_au` from `T_years`**.
# > - Mention that neural networks train better if you **scale** the data first
# >   (`StandardScaler`), and that you want to undo the scaling to read real values.
# > - Ask for one step at a time, run the code, and check that the result is reasonable.
# > - **You** are in charge: read the code, and judge whether the output makes sense.
# > - The exercises **build on each other**: run them in order and reuse the same variable names, so later cells can use what you made earlier.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## The data
#
# Run this cell so the data is available for the exercises below.

# %%
planets = pd.DataFrame({
    "planet":  ["Mercury","Venus","Earth","Mars","Jupiter","Saturn","Uranus","Neptune"],
    "T_years": [0.2408467, 0.61519726, 1.0000174, 1.8808158, 11.862615, 29.447498, 84.016846, 164.79132],
    "a_au":    [0.38709893, 0.72333199, 1.00000011, 1.52366231, 5.20336301, 9.53707032, 19.19126393, 30.06896348],
})
planets
# Out:
#     planet     T_years       a_au
# 0  Mercury    0.240847   0.387099
# 1    Venus    0.615197   0.723332
# 2    Earth    1.000017   1.000000
# 3     Mars    1.880816   1.523662
# 4  Jupiter   11.862615   5.203363
# 5   Saturn   29.447498   9.537070
# 6   Uranus   84.016846  19.191264
# 7  Neptune  164.791320  30.068963

# %% [markdown]
# ## Exercise 1 — Scale the data
#
# Prepare the data for a neural network: put `T_years` as the input `X` and `a_au` as the target
# `y`, and **scale** both (for example with `StandardScaler`). Ask the AI to help, then run the
# code below.

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 2 — Build and train the network
#
# Build a small neural network (e.g. `MLPRegressor` with one hidden layer of about 8 neurons and a
# `tanh` activation) that predicts the (scaled) semi-major axis from the (scaled) period, and train
# it on the data.

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 3 — See how well it fits
#
# Let the trained network predict $a$ across the whole range of periods, **undo the scaling**, and
# plot the prediction curve on top of the data. Also compute the loss (MSE) of the network.

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 4 — Compare with the power law
#
# Fit the power-law model $a = C\,T^{p}$ (as in Section 3) and compare its MSE with the neural
# network's MSE. Which one fits better? How many parameters does each one use?

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 5 — Experiment
#
# Change the network and see what happens: try a different number of neurons (e.g. 2, 16, or two
# hidden layers) or a different activation (`relu`, `logistic`). Does a bigger network always fit
# better?

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Done?
#
# Go back to the worksheet and answer the questions using your results.
#
# For the discussion afterwards, note: which prompts did you give the AI, did its code work straight
# away, and how did you check that the network's result was sensible?
