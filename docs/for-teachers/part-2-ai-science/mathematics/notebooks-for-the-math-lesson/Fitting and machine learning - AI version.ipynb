# %% [markdown]
# # Fitting and machine learning — write it yourself with AI
#
# In this version of the notebook **you** write the Python code, with the help of an AI language
# model (LLM).
#
# The planet data is already loaded for you in the first cells. After that, each exercise tells
# you *what* to do, but not *how*. For each exercise:
#
# 1. Read the task.
# 2. Ask the AI to help you write the Python code. Tell it that you have a pandas DataFrame
#    called `planets` with columns `T_years` (orbital period in years) and `a_au`
#    (semi-major axis in AU).
# 3. Paste the code into the empty cell, run it, and check that the result makes sense.
# 4. If you get an error, paste the error message back to the AI and ask it to fix the code.
#
# Work through the exercises in order — the later ones build on the earlier ones.

# %% [markdown]
# ## How to use this notebook
#
# New to Google Colab? A few basics:
#
# - **Run a cell** by clicking it and pressing **Shift + Enter** (or click the **▶** button on its left).
# - **Run the cells in order, from top to bottom.** A cell often needs things set up by the cells above it, so if you skip one you may get an error (for example a `NameError`).
# - The first time you run something, Colab may warn that the notebook **was not authored by Google**. Click **Run anyway**; this notebook only does calculations and makes plots.
# - If a cell shows a **red error**, read the **last line**, fix it (or ask your AI tutor) and run the cell again.
# - Anything you type or produce here is temporary, which is fine for this lesson.

# %% [markdown]
# > **Tips for working with the AI**
# >
# > - Be specific about your data: the DataFrame `planets`, columns `T_years` and `a_au`.
# > - Ask for one thing at a time.
# > - Always *read and run* the code it gives you, and check whether the answer is reasonable.
# > - **You** are in charge: if something looks wrong, ask again or ask it to explain.
# > - The exercises **build on each other**: run them in order and reuse the same variable names, so later cells can use what you made earlier.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## The data
#
# Orbital period $T$ (in years) and semi-major axis $a$ (in AU) for all eight planets.
# Run this cell so the data is available for the exercises below.

# %%
planets = pd.DataFrame({
    "planet":  ["Mercury","Venus","Earth","Mars","Jupiter","Saturn","Uranus","Neptune"],
    "T_years": [0.2408467, 0.61519726, 1.0000174, 1.8808158, 11.862615, 29.447498, 84.016846, 164.79132],
    "a_au":    [0.38709893, 0.72333199, 1.00000011, 1.52366231, 5.20336301, 9.53707032, 19.19126393, 30.06896348],
})
planets
# Out:
#     planet     T_years       a_au
# 0  Mercury    0.240847   0.387099
# 1    Venus    0.615197   0.723332
# 2    Earth    1.000017   1.000000
# 3     Mars    1.880816   1.523662
# 4  Jupiter   11.862615   5.203363
# 5   Saturn   29.447498   9.537070
# 6   Uranus   84.016846  19.191264
# 7  Neptune  164.791320  30.068963

# %% [markdown]
# ## Exercise 1 — Plot the data
#
# Make a scatter plot of the data, with the orbital period `T_years` on the **x-axis** and the
# semi-major axis `a_au` on the **y-axis**. Ask the AI to help you write the code, then run it below.

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 2 — Fit a linear model
#
# Fit a straight line through the origin, $a = c\,T$, to the data. Find the best value of $c$ and
# compute the loss (the mean squared error, MSE). You may fit on the four inner planets (as in the
# worksheet) or on all eight — just note which you did.

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 3 — Fit a quadratic model
#
# Fit a quadratic model $a = \alpha T^2 + \beta T + \gamma$ to all eight planets, and compute its
# MSE. *(Hint: numpy has a function that fits polynomials.)*

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 4 — Fit a power-law model
#
# Fit a power-law model $a = C\,T^{p}$ to all eight planets, and compute its MSE.
#
# *Hint: a power law becomes a straight line if you take the logarithm of both axes, because*
# $$ \log a = \log C + p\,\log T. $$

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Exercise 5 — Compare the models
#
# Put the MSE of the three models side by side and compare them. Which model fits best? What value
# did the power-law fit find for the exponent $p$? Finally, make one plot showing the data together
# with all three fitted models.

# %%
# Write your code here (ask the AI for help), then run this cell.

# %% [markdown]
# ## Done?
#
# Go back to the worksheet and answer the questions using your results.
#
# Also note, for the discussion afterwards: which prompts did you give the AI, and did its code work
# straight away, or did you have to correct it? How did you check that the answer was right?
